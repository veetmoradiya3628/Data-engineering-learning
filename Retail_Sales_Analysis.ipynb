# %% [markdown]
# <a href="https://colab.research.google.com/github/veetmoradiya3628/Data-engineering-learning/blob/main/Retail_Sales_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

class RetailSalesAnalyzer:
  def __init__(self) -> None:
    self.data = pd.read_csv('/content/retail_sales.csv')
    self.data['Date'] = pd.to_datetime(self.data['Date'])

  def data_clean(self):
    self.data.dropna(inplace=True)

  def total_sales_per_product(self):
    return self.data.groupby('Product')['Sales'].sum()

  def best_selling_product(self):
    return self.total_sales_per_product().sort_values(ascending=False).index[0]

  def average_daily_sales(self):
    return self.data['Sales'].mean()

  def plot_sales_trend(self):
    self.data.groupby('Date')['Sales'].sum().plot(kind='line')
    plt.title('Sales Trend')
    plt.xlabel('Date')
    plt.ylabel('Sales')
    plt.show()

  def plot_sales_per_product(self):
    self.total_sales_per_product().plot(kind='bar')
    plt.title('Sales per Product')
    plt.xlabel('Product')
    plt.ylabel('Sales')
    plt.show()

# %%
analyzer = RetailSalesAnalyzer()
analyzer.data_clean()
print(analyzer.total_sales_per_product())
print(analyzer.best_selling_product())
print(analyzer.average_daily_sales())
analyzer.plot_sales_trend()
analyzer.plot_sales_per_product()
# Out:
# Product
# Product A    130
# Product B    140
# Product C    150
# Name: Sales, dtype: int64
# Product C
# 52.5
